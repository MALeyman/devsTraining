# %% [markdown]
# # Задание ZALA
# ## 2. Детектирование множества объектов

# %% [markdown]
# __YOLOv8n__ (Ultralytics YOLOv8 Nano) – самый лёгкий вариант, быстрый.
#
# __MobileNetV3-SSD__ – лёгкая модель для детекции.
#
# __EfficientDet-D0__ – баланс качества и скорости.
#
# __NanoDet / PP-YOLOE-S__ – быстрые и эффективные.

# %%
model.info()
# Out:
# Model summary (fused): 72 layers, 11,129,454 parameters, 0 gradients, 28.5 GFLOPs
# (72, 11129454, 0, 28.457011199999997)

# %%
import cv2
from ultralytics import YOLO

# Параметры
video_path = "video1.avi"  # Путь к входному видео
output_video_path = "video_boxed.avi"  # Путь к выходному видео
model_path = "best8.pt"  # Файл обученной модели
conf_threshold = 0.1  # Порог уверенности
iou_threshold = 0.1  # Порог IoU


# Загружаем модель YOLO
model = YOLO(model_path)

# Открываем видео
cap = cv2.VideoCapture(video_path)

# Размер экрана
screen_width = 1024
screen_height = 1024

width = 512
height = 512

video_path = "video3.avi"  # Путь к входному видео
output_video_path = "video_boxed.avi"  # Путь к выходному видео
conf = 0.1
iou=0.2



# Открываем видео
cap = cv2.VideoCapture(video_path)

# Получаем информацию о видео (размер кадра, fps и т.д.)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Создаем объект VideoWriter для записи выходного видео
fourcc = cv2.VideoWriter_fourcc(*'XVID')  # Используем кодек XVID для AVI
out = cv2.VideoWriter(output_video_path, fourcc, 20, (screen_width, screen_height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    # Масштабируем кадр, чтобы он поместился в экран
    frame_resized = cv2.resize(frame, (screen_width, screen_height))
    img_resized = cv2.resize(frame, (width, height))
    # Применяем детекцию (модель, которая у тебя уже есть)
    results = model.predict(frame_resized, conf=conf, iou=iou)

    # Здесь выполняется рисование на кадре (если нужно)
    for result in results:
        boxes = result.boxes.xyxy.cpu().numpy()
        labels = result.boxes.cls.cpu().numpy()
        scores = result.boxes.conf.cpu().numpy()

        for box, label, score in zip(boxes, labels, scores):
            x1, y1, x2, y2 = map(int, box)
            frame_resized = cv2.rectangle(frame_resized, (x1, y1), (x2, y2), (0, 255, 0), 2)
    
    # Записываем кадр в выходное видео
    out.write(frame_resized)

    # Отображаем кадр
    cv2.imshow('Frame', frame_resized)
    
    # Прерываем по нажатию 'q'
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Завершаем захват и закрываем окна
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 512x512 30 buildings, 1 well, 5.1ms
# Speed: 1.4ms preprocess, 5.1ms inference, 84.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 30 buildings, 2 wells, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 30 buildings, 2 wells, 7.2ms
# Speed: 1.6ms preprocess, 7.2ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 31 buildings, 2 wells, 6.0ms
# Speed: 1.3ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 30 buildings, 2 wells, 5.3ms
# Speed: 1.4ms preprocess, 5.3ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 30 buildings, 2 wells, 5.7ms
# Speed: 1.9ms preprocess, 5.7ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 30 buildings, 2 wells, 5.0ms
# Speed: 1.7ms preprocess, 5.0ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 31 buildings, 2 wells, 6.0ms
# Speed: 1.3ms preprocess, 6.0ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 30 buildings, 1 well, 6.1ms
# Speed: 1.2ms preprocess, 6.1ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 1 well, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 1 well, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 30 buildings, 1 well, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 4.8ms
# Speed: 1.4ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 5.9ms
# Speed: 1.6ms preprocess, 5.9ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 3 wells, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 31 buildings, 3 wells, 4.8ms
# Speed: 1.4ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 4.8ms
# Speed: 1.6ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 2 wells, 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 1 well, 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 30 buildings, 1 well, 5.0ms
# Speed: 1.4ms preprocess, 5.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 30 buildings, 1 well, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 30 buildings, 1 well, 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 1 prefabricated-house, 2 wells, 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 2 wells, 5.9ms
# Speed: 1.3ms preprocess, 5.9ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 2 wells, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 4.8ms
# Speed: 1.5ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 5.0ms
# Speed: 1.3ms preprocess, 5.0ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 6.3ms
# Speed: 1.2ms preprocess, 6.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 30 buildings, 1 well, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 30 buildings, 1 well, 4.9ms
# Speed: 1.5ms preprocess, 4.9ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 30 buildings, 1 well, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 1 well, 5.0ms
# Speed: 1.6ms preprocess, 5.0ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 27 buildings, 1 well, 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 27 buildings, 1 well, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 27 buildings, 1 well, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 27 buildings, 1 well, 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 1 well, 6.2ms
# Speed: 1.3ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 1 well, 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 1 well, 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 1 well, 5.0ms
# Speed: 1.3ms preprocess, 5.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 27 buildings, 1 well, 6.0ms
# Speed: 1.4ms preprocess, 6.0ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 27 buildings, 1 well, 5.0ms
# Speed: 1.7ms preprocess, 5.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 27 buildings, 1 well, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 27 buildings, 1 well, 5.9ms
# Speed: 1.3ms preprocess, 5.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 27 buildings, 1 well, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 26 buildings, 1 well, 4.9ms
# Speed: 1.3ms preprocess, 4.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 1 well, 5.8ms
# Speed: 1.2ms preprocess, 5.8ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 2 wells, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 2 wells, 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 6.1ms
# Speed: 1.2ms preprocess, 6.1ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 2 wells, 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 2 wells, 4.8ms
# Speed: 1.4ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 30 buildings, 2 wells, 6.1ms
# Speed: 1.4ms preprocess, 6.1ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 30 buildings, 2 wells, 6.2ms
# Speed: 1.8ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 30 buildings, 2 wells, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 5.1ms
# Speed: 1.4ms preprocess, 5.1ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 2 wells, 5.0ms
# Speed: 1.3ms preprocess, 5.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 2 wells, 5.8ms
# Speed: 1.3ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 27 buildings, 2 wells, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 28 buildings, 2 wells, 5.0ms
# Speed: 1.7ms preprocess, 5.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 27 buildings, 2 wells, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 29 buildings, 2 wells, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 26 buildings, 2 wells, 4.9ms
# Speed: 1.3ms preprocess, 4.9ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 26 buildings, 2 wells, 5.9ms
# Speed: 1.3ms preprocess, 5.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 25 buildings, 2 wells, 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 27 buildings, 2 wells, 5.1ms
# Speed: 1.1ms preprocess, 5.1ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 25 buildings, 2 wells, 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 24 buildings, 2 wells, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 23 buildings, 2 wells, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 21 buildings, 2 wells, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 18 buildings, 2 wells, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 16 buildings, 2 wells, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 wells, 4.9ms
# Speed: 1.3ms preprocess, 4.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 11 buildings, 2 wells, 5.9ms
# Speed: 1.3ms preprocess, 5.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 9 buildings, 1 well, 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 9 buildings, 1 well, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 9 buildings, 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 9 buildings, 1 well, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 7 buildings, 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 6 buildings, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 6 buildings, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 6 buildings, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 6 buildings, 4.9ms
# Speed: 1.3ms preprocess, 4.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 7 buildings, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 7 buildings, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 11 buildings, 6.0ms
# Speed: 1.4ms preprocess, 6.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 11 buildings, 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 9 buildings, 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 7 buildings, 5.1ms
# Speed: 1.6ms preprocess, 5.1ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 buildings, 6.2ms
# Speed: 1.8ms preprocess, 6.2ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 7.4ms
# Speed: 1.2ms preprocess, 7.4ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.0ms
# Speed: 1.6ms preprocess, 5.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.9ms
# Speed: 1.2ms preprocess, 5.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.3ms
# Speed: 1.4ms preprocess, 5.3ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 6.0ms
# Speed: 1.4ms preprocess, 6.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.0ms
# Speed: 1.5ms preprocess, 5.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.9ms
# Speed: 1.4ms preprocess, 4.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.5ms
# Speed: 1.3ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.9ms
# Speed: 1.4ms preprocess, 4.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.9ms
# Speed: 1.2ms preprocess, 5.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.9ms
# Speed: 1.5ms preprocess, 4.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.9ms
# Speed: 1.6ms preprocess, 5.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 6.3ms
# Speed: 1.5ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 6.1ms
# Speed: 1.5ms preprocess, 6.1ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.8ms
# Speed: 1.3ms preprocess, 5.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.7ms
# Speed: 1.3ms preprocess, 5.7ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.1ms preprocess, 4.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 6.1ms
# Speed: 1.3ms preprocess, 6.1ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 6.9ms
# Speed: 1.2ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.0ms
# Speed: 1.3ms preprocess, 5.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 6.0ms
# Speed: 1.4ms preprocess, 6.0ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.9ms
# Speed: 1.2ms preprocess, 4.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.2ms
# Speed: 1.1ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.9ms
# Speed: 1.6ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.9ms
# Speed: 1.4ms preprocess, 4.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 6.0ms
# Speed: 1.4ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.2ms
# Speed: 1.7ms preprocess, 5.2ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.5ms preprocess, 4.8ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.9ms
# Speed: 1.2ms preprocess, 5.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.0ms
# Speed: 1.3ms preprocess, 5.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.0ms
# Speed: 1.5ms preprocess, 5.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 6.0ms
# Speed: 1.3ms preprocess, 6.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.8ms
# Speed: 1.2ms preprocess, 4.8ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 4.9ms
# Speed: 1.4ms preprocess, 4.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.0ms
# Speed: 1.3ms preprocess, 5.0ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
