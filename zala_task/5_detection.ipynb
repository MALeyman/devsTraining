# %% [markdown]
# Автор: Лейман М.А.
# Дата создания: 22.03.2025
#
# # Применение модели
# ### детектирование объектов на видео и фото
#
# ### Модель __YOLOv8n__ (Ultralytics YOLOv8 Nano)
#
# проверка работы обученной модели

# %%
# Параметры
video_path = "video/video3.avi"  # Путь к входному видео
s_output_video_path = "video/video_yolo_s.avi"  # Путь к выходному видео
s_model_path = "models/11s_best.pt"  # Файл обученной модели

n_output_video_path = "video/video_yolo_n.avi"  # Путь к выходному видео
n_model_path = "models/11n_best.pt"  # Файл обученной модели




from ultralytics import YOLO
import cv2


def video_detection(model_path, video_path, output_video_path):
    model = YOLO(model_path)

    # Настройки видео
    screen_width = 1024
    screen_height = 1024
    conf = 0.4
    iou = 0.5  # Можно снизить для более агрессивного NMS

    cap = cv2.VideoCapture(video_path)
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_video_path, fourcc, 20, (screen_width, screen_height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        frame_resized = cv2.resize(frame, (screen_width, screen_height))

        # Используем ByteTrack для уменьшения дрожания
        results = model.track(frame_resized, persist=True, conf=conf, iou=iou, agnostic_nms=True)

        for result in results:
            boxes = result.boxes.xyxy.cpu().numpy()
            labels = result.boxes.cls.cpu().numpy()
            scores = result.boxes.conf.cpu().numpy()
            track_ids = result.boxes.id.cpu().numpy() if result.boxes.id is not None else [None] * len(boxes)

            # for box, label, score, track_id in zip(boxes, labels, scores, track_ids):
            #     x1, y1, x2, y2 = map(int, box)
            #     frame_resized = cv2.rectangle(frame_resized, (x1, y1), (x2, y2), (0, 255, 0), 2)
                
            #     if track_id is not None:
            #         cv2.putText(frame_resized, f'ID: {int(track_id)}', (x1, y1 - 10),
            #                     cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)


            for box, label, score in zip(boxes, labels, scores):
                x1, y1, x2, y2 = map(int, box)
                class_name = model.names[int(label)]  # Получаем название класса
                cv2.rectangle(frame_resized, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame_resized, f'{class_name} {score:.2f}', (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

        out.write(frame_resized)
        cv2.imshow('Frame', frame_resized)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    out.release()
    cv2.destroyAllWindows()

# %%
video_detection(s_model_path, video_path = "video/video7.avi", output_video_path = "video/video_yolo_s3.avi")
# Out:
# 0: 512x512 2 vehicles, 6.1ms
# Speed: 0.9ms preprocess, 6.1ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 6.4ms
# Speed: 1.5ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 6.0ms
# Speed: 1.1ms preprocess, 6.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.5ms
# Speed: 1.3ms preprocess, 5.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.6ms
# Speed: 1.1ms preprocess, 5.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.9ms
# Speed: 1.2ms preprocess, 5.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.5ms
# Speed: 1.2ms preprocess, 5.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.8ms
# Speed: 1.2ms preprocess, 5.8ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.9ms
# Speed: 1.1ms preprocess, 5.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.6ms
# Speed: 1.2ms preprocess, 5.6ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.7ms
# Speed: 1.2ms preprocess, 5.7ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 6.0ms
# Speed: 1.3ms preprocess, 6.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.6ms
# Speed: 1.2ms preprocess, 5.6ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.7ms
# Speed: 1.3ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.4ms
# Speed: 1.4ms preprocess, 5.4ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 3 vehicles, 5.4ms
# Speed: 1.5ms preprocess, 5.4ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.6ms
# Speed: 1.2ms preprocess, 5.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.4ms
# Speed: 1.4ms preprocess, 5.4ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 6.0ms
# Speed: 1.3ms preprocess, 6.0ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.5ms
# Speed: 1.3ms preprocess, 5.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 6.0ms
# Speed: 1.1ms preprocess, 6.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.9ms
# Speed: 1.2ms preprocess, 5.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.7ms
# Speed: 1.3ms preprocess, 5.7ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.7ms
# Speed: 1.5ms preprocess, 5.7ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.7ms
# Speed: 1.2ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.5ms
# Speed: 1.3ms preprocess, 5.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.5ms
# Speed: 1.3ms preprocess, 5.5ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.2ms
# Speed: 1.4ms preprocess, 5.2ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.6ms
# Speed: 1.2ms preprocess, 5.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 7.5ms
# Speed: 1.3ms preprocess, 7.5ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.7ms
# Speed: 1.5ms preprocess, 5.7ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 6.0ms
# Speed: 1.3ms preprocess, 6.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.8ms
# Speed: 1.2ms preprocess, 5.8ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.6ms
# Speed: 1.2ms preprocess, 5.6ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.5ms
# Speed: 1.3ms preprocess, 5.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 (no detections), 5.4ms
# Speed: 1.6ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.7ms
# Speed: 1.4ms preprocess, 5.7ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.6ms
# Speed: 1.6ms preprocess, 5.6ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.3ms
# Speed: 1.5ms preprocess, 5.3ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.3ms
# Speed: 1.4ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.4ms
# Speed: 1.5ms preprocess, 5.4ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.3ms
# Speed: 1.5ms preprocess, 5.3ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.3ms
# Speed: 1.5ms preprocess, 5.3ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.5ms
# Speed: 1.2ms preprocess, 5.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.9ms
# Speed: 1.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 6.0ms
# Speed: 1.4ms preprocess, 6.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.3ms
# Speed: 1.3ms preprocess, 5.3ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.3ms
# Speed: 1.3ms preprocess, 5.3ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.7ms
# Speed: 1.3ms preprocess, 5.7ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.7ms
# Speed: 1.3ms preprocess, 5.7ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.5ms
# Speed: 1.6ms preprocess, 5.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.7ms
# Speed: 1.2ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.1ms
# Speed: 1.4ms preprocess, 5.1ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.3ms
# Speed: 1.3ms preprocess, 5.3ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.6ms
# Speed: 1.4ms preprocess, 5.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.7ms
# Speed: 1.4ms preprocess, 5.7ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.1ms
# Speed: 1.7ms preprocess, 5.1ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.3ms
# Speed: 1.3ms preprocess, 5.3ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.0ms
# Speed: 1.2ms preprocess, 5.0ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.5ms
# Speed: 1.8ms preprocess, 5.5ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 1 vehicle, 5.3ms
# Speed: 1.3ms preprocess, 5.3ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 6.0ms
# Speed: 1.2ms preprocess, 6.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.1ms
# Speed: 1.2ms preprocess, 5.1ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.2ms
# Speed: 1.2ms preprocess, 5.2ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.0ms
# Speed: 1.1ms preprocess, 5.0ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 2 vehicles, 5.4ms
# Speed: 1.1ms preprocess, 5.4ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)

# %%
video_detection(n_model_path, video_path = "video/video6.avi", output_video_path = "video/video_yolo_n.avi")
# Out:
# 0: 512x512 12 buildings, 2 prefabricated-houses, 7.3ms
# Speed: 1.4ms preprocess, 7.3ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 12 buildings, 2 prefabricated-houses, 7.3ms
# Speed: 2.4ms preprocess, 7.3ms inference, 4.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 12 buildings, 2 prefabricated-houses, 7.4ms
# Speed: 1.5ms preprocess, 7.4ms inference, 12.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 12 buildings, 2 prefabricated-houses, 6.8ms
# Speed: 3.5ms preprocess, 6.8ms inference, 5.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 12 buildings, 2 prefabricated-houses, 7.7ms
# Speed: 2.8ms preprocess, 7.7ms inference, 11.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 11 buildings, 2 prefabricated-houses, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 2.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 11 buildings, 2 prefabricated-houses, 8.6ms
# Speed: 3.8ms preprocess, 8.6ms inference, 12.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 12 buildings, 2 prefabricated-houses, 7.7ms
# Speed: 3.1ms preprocess, 7.7ms inference, 11.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 12 buildings, 2 prefabricated-houses, 7.6ms
# Speed: 1.3ms preprocess, 7.6ms inference, 7.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 7.6ms
# Speed: 3.3ms preprocess, 7.6ms inference, 11.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 6.6ms
# Speed: 2.5ms preprocess, 6.6ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 9.9ms
# Speed: 2.7ms preprocess, 9.9ms inference, 12.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 11 buildings, 2 prefabricated-houses, 9.0ms
# Speed: 2.4ms preprocess, 9.0ms inference, 12.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 12 buildings, 2 prefabricated-houses, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 11.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 12 buildings, 2 prefabricated-houses, 6.1ms
# Speed: 1.2ms preprocess, 6.1ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 7.8ms
# Speed: 1.1ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 12.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 12 buildings, 2 prefabricated-houses, 1 ship, 9.6ms
# Speed: 2.4ms preprocess, 9.6ms inference, 12.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 1 ship, 7.2ms
# Speed: 1.5ms preprocess, 7.2ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 1 ship, 8.1ms
# Speed: 2.8ms preprocess, 8.1ms inference, 12.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 1 ship, 10.0ms
# Speed: 3.3ms preprocess, 10.0ms inference, 12.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 1 ship, 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 5.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 2 prefabricated-houses, 1 ship, 7.9ms
# Speed: 1.6ms preprocess, 7.9ms inference, 9.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 2 prefabricated-houses, 1 ship, 5.8ms
# Speed: 1.5ms preprocess, 5.8ms inference, 4.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 7.2ms
# Speed: 2.9ms preprocess, 7.2ms inference, 8.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 7.2ms
# Speed: 1.3ms preprocess, 7.2ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 7.1ms
# Speed: 2.9ms preprocess, 7.1ms inference, 2.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 9.2ms
# Speed: 3.4ms preprocess, 9.2ms inference, 12.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 6.7ms
# Speed: 1.9ms preprocess, 6.7ms inference, 12.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 5.7ms
# Speed: 4.1ms preprocess, 5.7ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 4.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 6.8ms
# Speed: 1.2ms preprocess, 6.8ms inference, 9.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 8.9ms
# Speed: 2.3ms preprocess, 8.9ms inference, 11.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 6.7ms
# Speed: 1.3ms preprocess, 6.7ms inference, 12.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 2 prefabricated-houses, 7.3ms
# Speed: 1.3ms preprocess, 7.3ms inference, 11.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 2 prefabricated-houses, 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 12.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 8.9ms
# Speed: 1.5ms preprocess, 8.9ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 11.9ms
# Speed: 1.5ms preprocess, 11.9ms inference, 5.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 5.9ms
# Speed: 3.2ms preprocess, 5.9ms inference, 3.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 6.8ms
# Speed: 2.1ms preprocess, 6.8ms inference, 12.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 6.8ms
# Speed: 2.9ms preprocess, 6.8ms inference, 12.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 7.8ms
# Speed: 2.1ms preprocess, 7.8ms inference, 3.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 3 prefabricated-houses, 7.1ms
# Speed: 3.8ms preprocess, 7.1ms inference, 8.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 7.8ms
# Speed: 1.3ms preprocess, 7.8ms inference, 12.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 6.7ms
# Speed: 3.5ms preprocess, 6.7ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 9.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 2 prefabricated-houses, 6.5ms
# Speed: 1.1ms preprocess, 6.5ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 2 prefabricated-houses, 5.7ms
# Speed: 1.3ms preprocess, 5.7ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 7.1ms
# Speed: 1.2ms preprocess, 7.1ms inference, 2.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 1 ship, 6.6ms
# Speed: 3.5ms preprocess, 6.6ms inference, 10.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 1 ship, 7.3ms
# Speed: 1.3ms preprocess, 7.3ms inference, 12.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 1 ship, 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 3 prefabricated-houses, 1 ship, 9.0ms
# Speed: 3.1ms preprocess, 9.0ms inference, 12.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 3 prefabricated-houses, 6.8ms
# Speed: 2.6ms preprocess, 6.8ms inference, 12.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 3 prefabricated-houses, 7.4ms
# Speed: 3.5ms preprocess, 7.4ms inference, 6.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 6.8ms
# Speed: 1.9ms preprocess, 6.8ms inference, 12.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 5.9ms
# Speed: 1.4ms preprocess, 5.9ms inference, 3.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 7.1ms
# Speed: 2.9ms preprocess, 7.1ms inference, 12.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 6.8ms
# Speed: 2.4ms preprocess, 6.8ms inference, 12.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 6.7ms
# Speed: 2.4ms preprocess, 6.7ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 9.0ms
# Speed: 4.1ms preprocess, 9.0ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 2 prefabricated-houses, 5.5ms
# Speed: 1.5ms preprocess, 5.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 7.8ms
# Speed: 1.6ms preprocess, 7.8ms inference, 12.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 12.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 5.7ms
# Speed: 1.6ms preprocess, 5.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 9.9ms
# Speed: 2.9ms preprocess, 9.9ms inference, 10.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 6.8ms
# Speed: 1.5ms preprocess, 6.8ms inference, 2.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 2 prefabricated-houses, 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 2 prefabricated-houses, 8.7ms
# Speed: 1.6ms preprocess, 8.7ms inference, 3.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 6.8ms
# Speed: 4.4ms preprocess, 6.8ms inference, 12.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 3 prefabricated-houses, 7.4ms
# Speed: 1.6ms preprocess, 7.4ms inference, 12.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 3 prefabricated-houses, 6.0ms
# Speed: 1.2ms preprocess, 6.0ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 7.1ms
# Speed: 1.4ms preprocess, 7.1ms inference, 10.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 7.1ms
# Speed: 1.7ms preprocess, 7.1ms inference, 12.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 6.7ms
# Speed: 1.6ms preprocess, 6.7ms inference, 12.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 2 prefabricated-houses, 7.7ms
# Speed: 3.3ms preprocess, 7.7ms inference, 11.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 6.4ms
# Speed: 2.7ms preprocess, 6.4ms inference, 3.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 7.5ms
# Speed: 3.8ms preprocess, 7.5ms inference, 12.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 7.6ms
# Speed: 1.4ms preprocess, 7.6ms inference, 11.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 5.7ms
# Speed: 1.3ms preprocess, 5.7ms inference, 2.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 2.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 6.6ms
# Speed: 2.9ms preprocess, 6.6ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 7.6ms
# Speed: 3.1ms preprocess, 7.6ms inference, 11.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 8.3ms
# Speed: 3.1ms preprocess, 8.3ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 9.8ms
# Speed: 1.6ms preprocess, 9.8ms inference, 7.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 8.1ms
# Speed: 2.8ms preprocess, 8.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 5.4ms
# Speed: 1.4ms preprocess, 5.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 5.2ms
# Speed: 1.6ms preprocess, 5.2ms inference, 2.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 9.1ms
# Speed: 3.3ms preprocess, 9.1ms inference, 11.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 6.7ms
# Speed: 3.2ms preprocess, 6.7ms inference, 12.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 2 prefabricated-houses, 5.5ms
# Speed: 3.2ms preprocess, 5.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 7.2ms
# Speed: 2.8ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 6.2ms
# Speed: 2.7ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 6.3ms
# Speed: 1.2ms preprocess, 6.3ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 9.5ms
# Speed: 1.6ms preprocess, 9.5ms inference, 11.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 7.0ms
# Speed: 3.0ms preprocess, 7.0ms inference, 12.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 7.3ms
# Speed: 1.3ms preprocess, 7.3ms inference, 6.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 3 prefabricated-houses, 9.9ms
# Speed: 2.1ms preprocess, 9.9ms inference, 8.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 2 prefabricated-houses, 6.5ms
# Speed: 1.3ms preprocess, 6.5ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 2 prefabricated-houses, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 12.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 7.9ms
# Speed: 1.7ms preprocess, 7.9ms inference, 11.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 6.4ms
# Speed: 1.4ms preprocess, 6.4ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 12.0ms
# Speed: 3.6ms preprocess, 12.0ms inference, 7.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 7.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 16 buildings, 1 prefabricated-house, 6.6ms
# Speed: 3.2ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 16 buildings, 1 prefabricated-house, 6.1ms
# Speed: 2.6ms preprocess, 6.1ms inference, 2.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 16 buildings, 1 prefabricated-house, 9.1ms
# Speed: 3.9ms preprocess, 9.1ms inference, 12.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 16 buildings, 1 prefabricated-house, 7.6ms
# Speed: 2.8ms preprocess, 7.6ms inference, 12.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 16 buildings, 1 prefabricated-house, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 16 buildings, 1 prefabricated-house, 7.7ms
# Speed: 2.9ms preprocess, 7.7ms inference, 11.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 16 buildings, 1 prefabricated-house, 5.6ms
# Speed: 1.4ms preprocess, 5.6ms inference, 5.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 5.6ms
# Speed: 1.6ms preprocess, 5.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 3.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 7.4ms
# Speed: 4.1ms preprocess, 7.4ms inference, 12.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 7.6ms
# Speed: 2.1ms preprocess, 7.6ms inference, 11.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 4.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 16 buildings, 1 prefabricated-house, 10.9ms
# Speed: 1.5ms preprocess, 10.9ms inference, 11.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 16 buildings, 1 prefabricated-house, 12.9ms
# Speed: 5.3ms preprocess, 12.9ms inference, 9.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 6.1ms
# Speed: 4.0ms preprocess, 6.1ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 7.1ms
# Speed: 2.1ms preprocess, 7.1ms inference, 12.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 9.4ms
# Speed: 2.5ms preprocess, 9.4ms inference, 12.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 6.8ms
# Speed: 3.4ms preprocess, 6.8ms inference, 9.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 8.8ms
# Speed: 2.8ms preprocess, 8.8ms inference, 2.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 12.4ms
# Speed: 3.2ms preprocess, 12.4ms inference, 11.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 7.0ms
# Speed: 1.7ms preprocess, 7.0ms inference, 12.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 1.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 9.0ms
# Speed: 1.6ms preprocess, 9.0ms inference, 11.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 7.0ms
# Speed: 3.3ms preprocess, 7.0ms inference, 12.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 6.6ms
# Speed: 2.1ms preprocess, 6.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 6.7ms
# Speed: 3.8ms preprocess, 6.7ms inference, 12.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 5.6ms
# Speed: 1.4ms preprocess, 5.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 7.8ms
# Speed: 2.6ms preprocess, 7.8ms inference, 12.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 7.5ms
# Speed: 1.5ms preprocess, 7.5ms inference, 11.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 6.4ms
# Speed: 1.3ms preprocess, 6.4ms inference, 3.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 7.6ms
# Speed: 4.2ms preprocess, 7.6ms inference, 10.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 5.5ms
# Speed: 3.8ms preprocess, 5.5ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 7.2ms
# Speed: 3.2ms preprocess, 7.2ms inference, 6.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 8.2ms
# Speed: 1.2ms preprocess, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 7.5ms
# Speed: 1.5ms preprocess, 7.5ms inference, 12.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 7.3ms
# Speed: 3.5ms preprocess, 7.3ms inference, 12.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 5.7ms
# Speed: 1.1ms preprocess, 5.7ms inference, 3.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 0.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 6.0ms
# Speed: 1.3ms preprocess, 6.0ms inference, 6.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 7.7ms
# Speed: 3.4ms preprocess, 7.7ms inference, 4.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 5.5ms
# Speed: 2.4ms preprocess, 5.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 7.3ms
# Speed: 1.6ms preprocess, 7.3ms inference, 7.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 7.1ms
# Speed: 1.4ms preprocess, 7.1ms inference, 7.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 6.6ms
# Speed: 1.2ms preprocess, 6.6ms inference, 11.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 7.1ms
# Speed: 1.3ms preprocess, 7.1ms inference, 12.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 9.5ms
# Speed: 2.2ms preprocess, 9.5ms inference, 12.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 6.9ms
# Speed: 1.5ms preprocess, 6.9ms inference, 3.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 7.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 5.5ms
# Speed: 1.2ms preprocess, 5.5ms inference, 2.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 8.6ms
# Speed: 1.6ms preprocess, 8.6ms inference, 11.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 6.7ms
# Speed: 1.8ms preprocess, 6.7ms inference, 12.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 7.5ms
# Speed: 2.3ms preprocess, 7.5ms inference, 4.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 7.1ms
# Speed: 1.4ms preprocess, 7.1ms inference, 10.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 6.2ms
# Speed: 1.4ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 7.5ms
# Speed: 2.3ms preprocess, 7.5ms inference, 10.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 13 buildings, 1 prefabricated-house, 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 12.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 1 prefabricated-house, 9.6ms
# Speed: 3.9ms preprocess, 9.6ms inference, 12.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 6.9ms
# Speed: 1.2ms preprocess, 6.9ms inference, 12.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 8.4ms
# Speed: 1.6ms preprocess, 8.4ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 1 prefabricated-house, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 12.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 7.6ms
# Speed: 3.1ms preprocess, 7.6ms inference, 11.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 5.6ms
# Speed: 2.7ms preprocess, 5.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 6.7ms
# Speed: 2.6ms preprocess, 6.7ms inference, 12.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 9.3ms
# Speed: 2.4ms preprocess, 9.3ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 7.9ms
# Speed: 1.2ms preprocess, 7.9ms inference, 5.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 5.4ms
# Speed: 1.2ms preprocess, 5.4ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 9.8ms
# Speed: 4.4ms preprocess, 9.8ms inference, 11.6ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 7.0ms
# Speed: 2.6ms preprocess, 7.0ms inference, 12.2ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 6.9ms
# Speed: 1.2ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 6.7ms
# Speed: 1.5ms preprocess, 6.7ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 9.7ms
# Speed: 1.9ms preprocess, 9.7ms inference, 12.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 7.0ms
# Speed: 1.2ms preprocess, 7.0ms inference, 12.0ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 5.3ms
# Speed: 2.7ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 7.2ms
# Speed: 3.8ms preprocess, 7.2ms inference, 10.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 5.6ms
# Speed: 2.2ms preprocess, 5.6ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 7.2ms
# Speed: 1.4ms preprocess, 7.2ms inference, 12.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 7.6ms
# Speed: 2.2ms preprocess, 7.6ms inference, 12.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 14 buildings, 2 prefabricated-houses, 5.3ms
# Speed: 1.6ms preprocess, 5.3ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 7.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 9.5ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 12.0ms
# Speed: 3.2ms preprocess, 12.0ms inference, 1.8ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 12.8ms
# Speed: 3.2ms preprocess, 12.8ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 6.0ms
# Speed: 1.7ms preprocess, 6.0ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 7.3ms
# Speed: 2.9ms preprocess, 7.3ms inference, 10.4ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 5.3ms
# Speed: 1.2ms preprocess, 5.3ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# 0: 512x512 15 buildings, 2 prefabricated-houses, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 12.3ms postprocess per image at shape (1, 3, 512, 512)
